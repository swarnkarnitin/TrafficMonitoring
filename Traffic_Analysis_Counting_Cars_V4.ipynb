# %%
# !pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.178-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.178-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 826.0 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.178 ultralytics-thop-2.0.15

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

zip_file_path = '/content/drive/My Drive/Traffic_Videos/roboflow_images/vehicle.v3i.yolov11.zip'
extract_dir = './vehicle.v3i.yolov11'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file
if os.path.exists(zip_file_path):
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"Successfully unzipped {zip_file_path} to {extract_dir}")
else:
    print(f"Error: {zip_file_path} not found.")
# Out:
# Successfully unzipped /content/drive/My Drive/Traffic_Videos/roboflow_images/vehicle.v3i.yolov11.zip to ./vehicle.v3i.yolov11

# %% [markdown]
# Training the model on Roboflow data

# %%
from ultralytics import YOLO

# Load a YOLOv8n model
model = YOLO("yolov8n.pt")  # You can choose a different model size like yolov8s.pt, yolov8m.pt, etc.

# Train the model on the custom dataset
# Assuming your dataset has a data.yaml file in the extracted directory
data_config_path = './vehicle.v3i.yolov11/data.yaml'

if os.path.exists(data_config_path):
    results = model.train(data=data_config_path, epochs=40, imgsz=640) # You can adjust epochs and imgsz
    print("Training finished.")
else:
    print(f"Error: data.yaml not found at {data_config_path}. Please ensure your dataset is correctly extracted and contains a data.yaml file.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100%|██████████| 6.25M/6.25M [00:00<00:00, 145MB/s]
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./vehicle.v3i.yolov11/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100%|██████████| 755k/755k [00:00<00:00, 56.8MB/s]
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100%|██████████| 5.35M/5.35M [00:00<00:00, 102MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1574.6±701.8 MB/s, size: 65.3 KB)
# train: Scanning /content/vehicle.v3i.yolov11/train/labels... 6590 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6590/6590 [00:02<00:00, 2226.83it/s]
# train: New cache created: /content/vehicle.v3i.yolov11/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 888.9±568.5 MB/s, size: 60.7 KB)
# val: Scanning /content/vehicle.v3i.yolov11/valid/labels... 823 images, 0 backgrounds, 0 corrupt: 100%|██████████| 823/823 [00:00<00:00, 1021.89it/s]
# val: New cache created: /content/vehicle.v3i.yolov11/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      2.44G      1.676      2.136      1.346        117        640: 100%|██████████| 412/412 [02:05<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:09<00:00,  2.73it/s]
#                    all        823       4838      0.452      0.528       0.48       0.25
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      2.89G      1.652      1.608      1.346        126        640: 100%|██████████| 412/412 [02:00<00:00,  3.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.13it/s]
#                    all        823       4838       0.57      0.517      0.557      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      2.91G      1.651      1.466      1.353         96        640: 100%|██████████| 412/412 [01:58<00:00,  3.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.25it/s]
#                    all        823       4838      0.539      0.551      0.533      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      2.93G      1.633       1.39      1.354        103        640: 100%|██████████| 412/412 [01:56<00:00,  3.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.91it/s]
#                    all        823       4838      0.619      0.554       0.59      0.315
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      2.94G      1.612      1.307      1.339         96        640: 100%|██████████| 412/412 [01:58<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.60it/s]
#                    all        823       4838      0.655       0.59      0.643      0.348
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      2.96G      1.587       1.27      1.331         79        640: 100%|██████████| 412/412 [01:58<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.23it/s]
#                    all        823       4838      0.624      0.615      0.648      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      2.98G      1.584      1.227      1.324        123        640: 100%|██████████| 412/412 [02:00<00:00,  3.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.19it/s]
#                    all        823       4838       0.64      0.594      0.642      0.351
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      2.99G      1.564      1.195       1.31        138        640: 100%|██████████| 412/412 [01:56<00:00,  3.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:09<00:00,  2.83it/s]
#                    all        823       4838      0.642      0.621      0.665      0.376
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      3.01G      1.556      1.171      1.308         84        640: 100%|██████████| 412/412 [01:56<00:00,  3.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.91it/s]
#                    all        823       4838      0.671      0.619      0.678      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      3.03G      1.543      1.147      1.298        120        640: 100%|██████████| 412/412 [01:59<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.26it/s]
#                    all        823       4838      0.662      0.648      0.692       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      3.05G      1.537      1.134      1.301        150        640: 100%|██████████| 412/412 [02:00<00:00,  3.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.15it/s]
#                    all        823       4838      0.722      0.613      0.689      0.388
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      3.06G      1.526      1.129      1.295        109        640: 100%|██████████| 412/412 [02:00<00:00,  3.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.38it/s]
#                    all        823       4838      0.659      0.645      0.677      0.379
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      3.08G      1.513      1.106      1.284         85        640: 100%|██████████| 412/412 [01:58<00:00,  3.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.86it/s]
#                    all        823       4838      0.651      0.657      0.699      0.382
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40       3.1G      1.513      1.092      1.282         91        640: 100%|██████████| 412/412 [02:01<00:00,  3.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  4.03it/s]
#                    all        823       4838      0.668      0.639      0.697      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      3.11G      1.498      1.069      1.275         81        640: 100%|██████████| 412/412 [02:00<00:00,  3.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.30it/s]
#                    all        823       4838      0.687      0.647      0.707      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      3.13G      1.499      1.072      1.276        135        640: 100%|██████████| 412/412 [02:06<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.85it/s]
#                    all        823       4838       0.68      0.678      0.722       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      3.15G      1.494      1.056      1.269        116        640: 100%|██████████| 412/412 [02:02<00:00,  3.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  4.01it/s]
#                    all        823       4838      0.717      0.652      0.727      0.414
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      3.17G      1.493      1.046      1.268        137        640: 100%|██████████| 412/412 [01:59<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.57it/s]
#                    all        823       4838      0.718       0.64      0.721      0.409
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      3.18G      1.486      1.042      1.268        112        640: 100%|██████████| 412/412 [01:59<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.15it/s]
#                    all        823       4838      0.663      0.672      0.714      0.411
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40       3.2G      1.478      1.031      1.262         71        640: 100%|██████████| 412/412 [02:02<00:00,  3.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.23it/s]
#                    all        823       4838      0.705      0.655      0.728      0.416
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      3.22G      1.482      1.013      1.265        117        640: 100%|██████████| 412/412 [02:01<00:00,  3.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.16it/s]
#                    all        823       4838      0.698      0.692       0.74      0.423
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      3.23G      1.477      1.016      1.259        128        640: 100%|██████████| 412/412 [01:57<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.23it/s]
#                    all        823       4838      0.695        0.7      0.746      0.426
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      3.25G      1.454      1.003      1.253        146        640: 100%|██████████| 412/412 [01:58<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.91it/s]
#                    all        823       4838      0.703      0.662      0.732      0.418
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      3.27G      1.457     0.9981      1.254        149        640: 100%|██████████| 412/412 [01:59<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.40it/s]
#                    all        823       4838      0.699      0.671      0.737      0.428
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      3.29G      1.457     0.9932      1.249         87        640: 100%|██████████| 412/412 [01:57<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.26it/s]
#                    all        823       4838      0.705       0.67      0.738      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40       3.3G      1.446     0.9767      1.246        142        640: 100%|██████████| 412/412 [01:55<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.93it/s]
#                    all        823       4838      0.694      0.679      0.744      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      3.32G      1.445     0.9649      1.242        100        640: 100%|██████████| 412/412 [02:00<00:00,  3.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.52it/s]
#                    all        823       4838      0.693      0.682      0.734      0.423
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      3.34G      1.442     0.9582      1.238        158        640: 100%|██████████| 412/412 [01:57<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.20it/s]
#                    all        823       4838      0.685      0.699      0.744      0.432
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      3.35G      1.427     0.9468      1.231        173        640: 100%|██████████| 412/412 [01:57<00:00,  3.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.80it/s]
#                    all        823       4838      0.699      0.693      0.749      0.431
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      3.37G      1.425     0.9487      1.235        106        640: 100%|██████████| 412/412 [01:55<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.64it/s]
#                    all        823       4838      0.703      0.681      0.746      0.434
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      3.39G      1.482     0.9138      1.265         43        640: 100%|██████████| 412/412 [01:55<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  4.04it/s]
#                    all        823       4838       0.68      0.721      0.757      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40       3.4G      1.468     0.8969      1.255         48        640: 100%|██████████| 412/412 [01:53<00:00,  3.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.31it/s]
#                    all        823       4838      0.715      0.688       0.75      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      3.42G      1.466      0.886      1.257         74        640: 100%|██████████| 412/412 [01:54<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.97it/s]
#                    all        823       4838      0.701      0.697      0.751      0.438
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      3.44G      1.449     0.8763      1.252         77        640: 100%|██████████| 412/412 [01:52<00:00,  3.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.66it/s]
#                    all        823       4838      0.719      0.689      0.761      0.442
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      3.46G      1.452     0.8655      1.249         70        640: 100%|██████████| 412/412 [01:55<00:00,  3.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.30it/s]
#                    all        823       4838      0.701      0.698      0.757       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      3.47G      1.446     0.8626      1.245         50        640: 100%|██████████| 412/412 [01:53<00:00,  3.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.90it/s]
#                    all        823       4838      0.736      0.672      0.755      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      3.49G      1.435     0.8535      1.241         78        640: 100%|██████████| 412/412 [01:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.18it/s]
#                    all        823       4838      0.688      0.712      0.756      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      3.51G      1.429     0.8485      1.236         69        640: 100%|██████████| 412/412 [01:55<00:00,  3.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.87it/s]
#                    all        823       4838      0.709      0.706       0.76      0.445
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      3.53G      1.424     0.8414       1.23         80        640: 100%|██████████| 412/412 [01:54<00:00,  3.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.29it/s]
#                    all        823       4838      0.745      0.682      0.762      0.444
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      3.54G      1.419      0.833      1.231         81        640: 100%|██████████| 412/412 [01:52<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.27it/s]
#                    all        823       4838      0.735      0.687      0.763      0.446
# 40 epochs completed in 1.401 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.178 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:11<00:00,  2.23it/s]
#                    all        823       4838      0.735      0.688      0.763      0.446
#                    bus        464        692      0.808      0.841      0.904       0.62
#                    car        592       2090       0.72      0.754      0.798      0.436
#               microbus        295        375      0.739      0.701      0.788      0.505
#              motorbike        509       1276      0.782       0.56      0.735      0.309
#             pickup-van        271        335      0.706      0.684      0.739      0.452
#                  truck         59         70      0.655      0.586      0.613      0.353
# Speed: 0.4ms preprocess, 2.4ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to runs/detect/train
# Training finished.

# %% [markdown]
# Running object detection on our data

# %%
import cv2
import os

# Define output video file path and filename
output_video_path = "output_video.avi"

# Re-open video file to ensure it's at the beginning
video_path = "/content/drive/MyDrive/Traffic_Videos/Mundhawan_Circle_SLR_1_Part2.MOV"
video_cap = cv2.VideoCapture(video_path)

# Check if the video capture was successful
if not video_cap.isOpened():
    print(f"Error: Could not open video file {video_path}")
else:
    # Get video properties from the re-opened video_cap
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))

    print(f"Frame Width: {frame_width}, Frame Height: {frame_height}, FPS: {fps}")

    # Define the video codec
    fourcc = cv2.VideoWriter_fourcc(*'XVID')

    # Create VideoWriter object
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    print(f"VideoWriter initialized: {out.isOpened()}")

    if not out.isOpened():
        print(f"Error: Could not initialize VideoWriter with codec {fourcc} for path {output_video_path}")
    else:
        # Load the best.pt model
        model = YOLO("./runs/detect/train/weights/best.pt")

        # Now start the processing loop
        while True:
            ret, frame = video_cap.read()
            if not ret:
                break

            # Run YOLO detection
            results = model(frame)

            # Draw bounding boxes for detected objects (using the class names from your trained model)
            for r in results:
                boxes = r.boxes
                for box in boxes:
                    x1, y1, x2, y2 = box.xyxy[0]
                    confidence = box.conf[0]
                    class_id = box.cls[0]
                    label = model.names[int(class_id)]
                    # You can add a confidence threshold here if needed
                    # if confidence > 0.5:
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, f"{label} {confidence:.2f}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

            # Write the processed frame to the output video file
            out.write(frame)

        print("Video processing finished.")

    # Release video capture and writer objects
    video_cap.release()
    if out.isOpened():
        out.release()

cv2.destroyAllWindows()

# %%
# import cv2

# # Define output video file path and filename
# output_video_path = "output_video.avi"

# # Re-open video file to ensure it's at the beginning
# video_cap = cv2.VideoCapture("/content/drive/My Drive/Traffic_Videos/Mundhawan_Circlet2.MOV")

# # Get video properties from the re-opened video_cap
# frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
# fps = int(video_cap.get(cv2.CAP_PROP_FPS))

# print(f"Frame Width: {frame_width}, Frame Height: {frame_height}, FPS: {fps}")

# # Define the video codec
# fourcc = cv2.VideoWriter_fourcc(*'XVID')

# # Create VideoWriter object
# out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# print(f"VideoWriter initialized: {out.isOpened()}")

# # Now start the processing loop
# while True:
#   ret, frame = video_cap.read()
#   if not ret:
#     break

#   # Run YOLO detection
#   results = model(frame)

#   # Draw bounding boxes for detected cars
#   for result in results[0].boxes.data.tolist():
#     x1, y1, x2, y2, confidence, class_id = result
#     if int(class_id) == 2: # Class ID 2 corresponds to 'car' in COCO dataset
#       cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

#   # Write the processed frame to the output video file
#   out.write(frame)

# # Release video capture and writer objects
# video_cap.release()
# out.release()
# cv2.destroyAllWindows()

# %%
# # Open video file
# video_cap = cv2.VideoCapture("/content/drive/My Drive/Traffic_Videos/Mundhawan_Circlet2.MOV")

# while True:
#   ret, frame = video_cap.read()
#   if not ret:
#     break

#   # Run YOLO detection
#   results = model(frame)

#   # Draw bounding boxes for detected cars
#   for result in results[0].boxes.data.tolist():
#     x1, y1, x2, y2, confidence, class_id = result
#     if int(class_id) == 2: # Class ID 2 corresponds to 'car' in COCO dataset
#       cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

#   cv2.imshow("Car Detection", frame)
#   if cv2.waitKey(1) & 0xFF == ord('q'):
#     break

# video_cap.release()
# cv2.destroyAllWindows()

# %%
# video_cap = cv2.VideoCapture("/content/drive/My Drive/Traffic_Videos/Mundhawan_Circlet2.MOV")

# %% [markdown]
# **Reasoning**:
# Call the loaded YOLO model on the current frame and store the results.

# %%
# for result in results[0].boxes.data.tolist():
#   x1, y1, x2, y2, confidence, class_id = result
#   if int(class_id) == 2: # Class ID 2 corresponds to 'car' in COCO dataset
#     cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

# %%
# import cv2
# import os

# # Define output video file path and filename
# output_video_path = "output_video.avi"

# # Re-open video file to ensure it's at the beginning
# video_path = "/content/drive/MyDrive/Traffic_Videos/Mundhawan_Circle_SLR_1_Part2.MOV"
# video_cap = cv2.VideoCapture(video_path)

# # Check if the video capture was successful
# if not video_cap.isOpened():
#     print(f"Error: Could not open video file {video_path}")
# else:
#     # Get video properties from the re-opened video_cap
#     frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#     frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#     fps = int(video_cap.get(cv2.CAP_PROP_FPS))

#     print(f"Frame Width: {frame_width}, Frame Height: {frame_height}, FPS: {fps}")

#     # Define the video codec
#     fourcc = cv2.VideoWriter_fourcc(*'XVID')

#     # Create VideoWriter object
#     out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

#     print(f"VideoWriter initialized: {out.isOpened()}")

#     if not out.isOpened():
#         print(f"Error: Could not initialize VideoWriter with codec {fourcc} for path {output_video_path}")
#     else:
#         # Load the best.pt model
#         model = YOLO("./runs/detect/train/weights/best.pt")

#         # Now start the processing loop
#         while True:
#             ret, frame = video_cap.read()
#             if not ret:
#                 break

#             # Run YOLO detection
#             results = model(frame)

#             # Draw bounding boxes for detected objects (using the class names from your trained model)
#             for r in results:
#                 boxes = r.boxes
#                 for box in boxes:
#                     x1, y1, x2, y2 = box.xyxy[0]
#                     confidence = box.conf[0]
#                     class_id = box.cls[0]
#                     label = model.names[int(class_id)]
#                     # You can add a confidence threshold here if needed
#                     # if confidence > 0.5:
#                     cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
#                     cv2.putText(frame, f"{label} {confidence:.2f}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#             # Write the processed frame to the output video file
#             out.write(frame)

#         print("Video processing finished.")

#     # Release video capture and writer objects
#     video_cap.release()
#     if out.isOpened():
#         out.release()

# cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 2.0ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 1 microbus, 6 motorbikes, 1 pickup-van, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 cars, 1 microbus, 7 motorbikes, 1 pickup-van, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 9 motorbikes, 1 pickup-van, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 8 motorbikes, 1 pickup-van, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 8 motorbikes, 1 pickup-van, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 9 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 10 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 8 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 9 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 8 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 8 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 8 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 10 motorbikes, 1 pickup-van, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 9 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 8 motorbikes, 1 pickup-van, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 8 motorbikes, 1 pickup-van, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 8 motorbikes, 1 pickup-van, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 7 motorbikes, 1 pickup-van, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 7 motorbikes, 1 pickup-van, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 6 motorbikes, 1 pickup-van, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 7 motorbikes, 1 pickup-van, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 5 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 5 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 5 motorbikes, 1 pickup-van, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 7 motorbikes, 1 pickup-van, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 7 motorbikes, 1 pickup-van, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 5 motorbikes, 1 pickup-van, 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 6 motorbikes, 2 pickup-vans, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 10 motorbikes, 1 pickup-van, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 12 motorbikes, 2 pickup-vans, 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 3 pickup-vans, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 10 motorbikes, 2 pickup-vans, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 2 pickup-vans, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 9 motorbikes, 2 pickup-vans, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 9 motorbikes, 2 pickup-vans, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 2 pickup-vans, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 2 pickup-vans, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 8 motorbikes, 2 pickup-vans, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 7 motorbikes, 2 pickup-vans, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 9 motorbikes, 2 pickup-vans, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 9 motorbikes, 2 pickup-vans, 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 2 pickup-vans, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 2 pickup-vans, 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 2 pickup-vans, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 2 pickup-vans, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 3 pickup-vans, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 2 pickup-vans, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 10 motorbikes, 1 pickup-van, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 1 pickup-van, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 10 motorbikes, 1 pickup-van, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 10.4ms
# Speed: 1.7ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 12 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 11 motorbikes, 1 pickup-van, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 9 motorbikes, 1 pickup-van, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 10 motorbikes, 1 pickup-van, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 11 motorbikes, 1 pickup-van, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 12 motorbikes, 1 pickup-van, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 12 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 11 motorbikes, 1 pickup-van, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 13 motorbikes, 2 pickup-vans, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 12 motorbikes, 1 pickup-van, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 11 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 14 motorbikes, 1 pickup-van, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 13 motorbikes, 1 pickup-van, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 13 motorbikes, 1 pickup-van, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 cars, 14 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 12 motorbikes, 1 pickup-van, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 12 motorbikes, 1 pickup-van, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 cars, 12 motorbikes, 1 pickup-van, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 cars, 13 motorbikes, 1 pickup-van, 14.6ms
# Speed: 1.7ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 cars, 13 motorbikes, 1 pickup-van, 15.3ms
# Speed: 2.6ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 13 motorbikes, 1 pickup-van, 16.0ms
# Speed: 2.6ms preprocess, 16.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 14 motorbikes, 1 pickup-van, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 15 motorbikes, 1 pickup-van, 9.4ms
# Speed: 3.1ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 13 motorbikes, 1 pickup-van, 9.8ms
# Speed: 6.3ms preprocess, 9.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 12 motorbikes, 1 pickup-van, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 1 pickup-van, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 12 motorbikes, 1 pickup-van, 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 1 microbus, 13 motorbikes, 1 pickup-van, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 1 microbus, 10 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 1 microbus, 11 motorbikes, 1 pickup-van, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 1 microbus, 12 motorbikes, 2 pickup-vans, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 11 motorbikes, 1 pickup-van, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 13 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 14 motorbikes, 2 pickup-vans, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 13 motorbikes, 2 pickup-vans, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 12 motorbikes, 1 pickup-van, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 10 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 13 motorbikes, 1 pickup-van, 14.4ms
# Speed: 3.6ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 13 motorbikes, 2 pickup-vans, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 12 motorbikes, 1 pickup-van, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 1 microbus, 13 motorbikes, 2 pickup-vans, 13.2ms
# Speed: 1.8ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 2 pickup-vans, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 12 motorbikes, 2 pickup-vans, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 2 pickup-vans, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 12 motorbikes, 1 pickup-van, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 13 motorbikes, 1 pickup-van, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 14.1ms
# Speed: 1.8ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 12 motorbikes, 2 pickup-vans, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 12 motorbikes, 1 pickup-van, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 15 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 14 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 12 motorbikes, 1 pickup-van, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 13 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 13 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 11 motorbikes, 1 pickup-van, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 12 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 14 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 14 motorbikes, 1 pickup-van, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 13 motorbikes, 1 pickup-van, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 13 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 12 motorbikes, 1 pickup-van, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 13 motorbikes, 1 pickup-van, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 12 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 11 motorbikes, 1 pickup-van, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 12 motorbikes, 1 pickup-van, 8.3ms
# Speed: 5.6ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 11 motorbikes, 1 pickup-van, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 12 motorbikes, 1 pickup-van, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 11 motorbikes, 1 pickup-van, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 12 motorbikes, 2 pickup-vans, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 12 motorbikes, 2 pickup-vans, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 14 motorbikes, 2 pickup-vans, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 2 pickup-vans, 13.3ms
# Speed: 2.1ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 13 motorbikes, 1 pickup-van, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 14 motorbikes, 1 pickup-van, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 15 motorbikes, 2 pickup-vans, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 13 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 13 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 12 motorbikes, 1 pickup-van, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 12 motorbikes, 1 pickup-van, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 11 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 12 motorbikes, 1 pickup-van, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 12 motorbikes, 1 pickup-van, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 cars, 13 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 cars, 13 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 13 motorbikes, 1 pickup-van, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 14 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 12 motorbikes, 2 pickup-vans, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 10 motorbikes, 2 pickup-vans, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 10 motorbikes, 1 pickup-van, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 cars, 11 motorbikes, 2 pickup-vans, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 cars, 11 motorbikes, 2 pickup-vans, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 10 motorbikes, 2 pickup-vans, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 2 pickup-vans, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 2 pickup-vans, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 2 pickup-vans, 9.3ms
# Speed: 4.9ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 12 motorbikes, 2 pickup-vans, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 12 motorbikes, 2 pickup-vans, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 12 motorbikes, 2 pickup-vans, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 12 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 10 motorbikes, 1 pickup-van, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 11 motorbikes, 1 pickup-van, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 9 motorbikes, 2 pickup-vans, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 9 motorbikes, 2 pickup-vans, 11.9ms
# Speed: 3.4ms preprocess, 11.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 9 motorbikes, 2 pickup-vans, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 2 pickup-vans, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 1 pickup-van, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 8 motorbikes, 1 pickup-van, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 7 motorbikes, 1 pickup-van, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 7 motorbikes, 1 pickup-van, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 7 motorbikes, 1 pickup-van, 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 7 motorbikes, 1 pickup-van, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 8 motorbikes, 1 pickup-van, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 12 motorbikes, 1 pickup-van, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 15.0ms
# Speed: 1.7ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 13 motorbikes, 1 pickup-van, 12.8ms
# Speed: 2.2ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 12 motorbikes, 1 pickup-van, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 12 motorbikes, 1 pickup-van, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 9 motorbikes, 1 pickup-van, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 11 motorbikes, 1 pickup-van, 9.7ms
# Speed: 3.5ms preprocess, 9.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.6ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 2 pickup-vans, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 11 motorbikes, 1 pickup-van, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 12 motorbikes, 1 pickup-van, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 13 motorbikes, 1 pickup-van, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 11 motorbikes, 1 pickup-van, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 13 motorbikes, 1 pickup-van, 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 14 cars, 12 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 12 motorbikes, 1 pickup-van, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 10 motorbikes, 1 pickup-van, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 11 motorbikes, 1 pickup-van, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 11 motorbikes, 1 pickup-van, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 11 motorbikes, 1 pickup-van, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 1 pickup-van, 12.4ms
# Speed: 3.2ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 9 motorbikes, 1 pickup-van, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 9 motorbikes, 1 pickup-van, 17.7ms
# Speed: 3.0ms preprocess, 17.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 9 motorbikes, 2 pickup-vans, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 12 motorbikes, 1 pickup-van, 14.9ms
# Speed: 1.8ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 11 motorbikes, 1 pickup-van, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 12 motorbikes, 1 pickup-van, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 9 motorbikes, 1 pickup-van, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 1 pickup-van, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 11 motorbikes, 1 pickup-van, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 13 motorbikes, 1 pickup-van, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 9 motorbikes, 1 pickup-van, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 15 cars, 11 motorbikes, 1 pickup-van, 11.3ms
# Speed: 2.7ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 11 motorbikes, 1 pickup-van, 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 1 pickup-van, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 9 motorbikes, 1 pickup-van, 12.6ms
# Speed: 3.2ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 9 motorbikes, 1 pickup-van, 12.3ms
# Speed: 2.3ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 2 pickup-vans, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 1 pickup-van, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 9 motorbikes, 1 pickup-van, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 9 motorbikes, 1 pickup-van, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 14 motorbikes, 1 pickup-van, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 11 motorbikes, 1 pickup-van, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 16 cars, 10 motorbikes, 1 pickup-van, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 9 motorbikes, 1 pickup-van, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 9 motorbikes, 1 pickup-van, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 10 motorbikes, 1 pickup-van, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 9.7ms
# Speed: 1.6ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 9 motorbikes, 1 pickup-van, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 11 motorbikes, 1 pickup-van, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 1 pickup-van, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 10 motorbikes, 1 pickup-van, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 11 motorbikes, 1 pickup-van, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 12 motorbikes, 1 pickup-van, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 13 motorbikes, 1 pickup-van, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 13 motorbikes, 1 pickup-van, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 11 motorbikes, 1 pickup-van, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 11 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 11 motorbikes, 1 pickup-van, 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 12 motorbikes, 1 pickup-van, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 10 motorbikes, 1 pickup-van, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 11 motorbikes, 1 pickup-van, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 26 cars, 10 motorbikes, 1 pickup-van, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 27 cars, 10 motorbikes, 1 pickup-van, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 11 motorbikes, 1 pickup-van, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 25 cars, 10 motorbikes, 1 pickup-van, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 22 cars, 10 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 23 cars, 10 motorbikes, 1 pickup-van, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 24 cars, 7 motorbikes, 1 pickup-van, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 7 motorbikes, 1 pickup-van, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 7 motorbikes, 1 pickup-van, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 7 motorbikes, 1 pickup-van, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 6 motorbikes, 1 pickup-van, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 18 cars, 7 motorbikes, 1 pickup-van, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 10 motorbikes, 1 pickup-van, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 9.2ms
# Speed: 2.8ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 8 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 8 motorbikes, 1 pickup-van, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 9 motorbikes, 1 pickup-van, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 8 motorbikes, 1 pickup-van, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 21 cars, 8 motorbikes, 1 pickup-van, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 9 motorbikes, 1 pickup-van, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 20 cars, 9 motorbikes, 1 pickup-van, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 8 motorbikes, 1 pickup-van, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 19 cars, 8 motorbikes, 1 pickup-van, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 17 cars, 9 motorbikes, 1 pickup-van, 9.8ms
# ...
#
# 0: 480x640 19 cars, 19 motorbikes, 3 pickup-vans, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.1ms
# Speed: 2.1ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.7ms
# Speed: 4.6ms preprocess, 8.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.0ms
# Speed: 1.7ms preprocess, 12.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 14.5ms
# Speed: 1.8ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.4ms
# Speed: 3.3ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 3.6ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 12.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 14.5ms
# Speed: 4.7ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.3ms
# Speed: 2.3ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.5ms
# Speed: 5.3ms preprocess, 8.5ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 13.5ms
# Speed: 1.8ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 12.7ms
# Speed: 1.8ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 truck, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Video processing finished.

# %%
# import os
# import shutil

# source_path = "output_video.avi"
# destination_path = "/content/output_video.avi"

# if os.path.exists(source_path):
#     shutil.copy(source_path, destination_path)
#     print(f"Successfully copied {source_path} to {destination_path}")
# else:
#     print(f"Error: {source_path} not found.")
# Out:
# Error: output_video.avi not found.

# %%
# from ultralytics import YOLO

# # Load a YOLOv8n model
# model = YOLO("yolov8n.pt")  # You can choose a different model size like yolov8s.pt, yolov8m.pt, etc.

# # Train the model on the custom dataset
# # Assuming your dataset has a data.yaml file in the extracted directory
# data_config_path = './vehicle.v3i.yolov11/data.yaml'

# if os.path.exists(data_config_path):
#     results = model.train(data=data_config_path, epochs=100, imgsz=640) # You can adjust epochs and imgsz
#     print("Training finished.")
# else:
#     print(f"Error: data.yaml not found at {data_config_path}. Please ensure your dataset is correctly extracted and contains a data.yaml file.")
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./vehicle.v3i.yolov11/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100%|██████████| 755k/755k [00:00<00:00, 13.9MB/s]
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100%|██████████| 5.35M/5.35M [00:00<00:00, 49.2MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1333.4±741.0 MB/s, size: 65.3 KB)
# train: Scanning /content/vehicle.v3i.yolov11/train/labels... 6590 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6590/6590 [00:02<00:00, 2305.82it/s]
# train: New cache created: /content/vehicle.v3i.yolov11/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1020.3±674.0 MB/s, size: 60.7 KB)
# val: Scanning /content/vehicle.v3i.yolov11/valid/labels... 823 images, 0 backgrounds, 0 corrupt: 100%|██████████| 823/823 [00:01<00:00, 814.85it/s]
# val: New cache created: /content/vehicle.v3i.yolov11/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.43G      1.685      2.468      1.381        117        640: 100%|██████████| 412/412 [02:15<00:00,  3.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:10<00:00,  2.55it/s]
#                    all        823       4838      0.506      0.473      0.473      0.248
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.88G      1.641      1.743      1.358        126        640: 100%|██████████| 412/412 [02:09<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.24it/s]
#                    all        823       4838      0.605       0.52      0.553       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.89G      1.662      1.651       1.37         96        640: 100%|██████████| 412/412 [02:09<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  2.93it/s]
#                    all        823       4838      0.517      0.504      0.499      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       2.9G      1.685       1.59      1.398        103        640: 100%|██████████| 412/412 [02:06<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.27it/s]
#                    all        823       4838      0.502      0.463      0.465      0.245
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.91G      1.661      1.467      1.378         96        640: 100%|██████████| 412/412 [02:09<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.44it/s]
#                    all        823       4838      0.615      0.554      0.587      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G       1.63      1.385      1.366         79        640: 100%|██████████| 412/412 [02:06<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.04it/s]
#                    all        823       4838      0.601      0.519      0.565      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.93G      1.627      1.335      1.355        123        640: 100%|██████████| 412/412 [02:07<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.04it/s]
#                    all        823       4838      0.591      0.596      0.622      0.338
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.95G      1.604      1.289      1.345        138        640: 100%|██████████| 412/412 [02:05<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.21it/s]
#                    all        823       4838      0.607      0.584      0.617      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.96G      1.601      1.263      1.342         84        640: 100%|██████████| 412/412 [02:07<00:00,  3.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.88it/s]
#                    all        823       4838      0.678      0.582      0.647      0.344
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.97G      1.584      1.229      1.334        120        640: 100%|██████████| 412/412 [02:07<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.14it/s]
#                    all        823       4838      0.652      0.608      0.646      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.98G      1.576      1.207      1.331        150        640: 100%|██████████| 412/412 [02:06<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.10it/s]
#                    all        823       4838      0.673      0.591      0.661      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.99G       1.57      1.206      1.327        109        640: 100%|██████████| 412/412 [02:06<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.84it/s]
#                    all        823       4838      0.701      0.583      0.672      0.375
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         3G      1.558      1.182      1.318         85        640: 100%|██████████| 412/412 [02:08<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.33it/s]
#                    all        823       4838      0.629       0.61       0.66      0.364
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      3.01G      1.554      1.164      1.314         91        640: 100%|██████████| 412/412 [02:05<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.12it/s]
#                    all        823       4838      0.658      0.605      0.669      0.375
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      3.03G      1.539       1.14      1.307         81        640: 100%|██████████| 412/412 [02:07<00:00,  3.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.40it/s]
#                    all        823       4838      0.713      0.607      0.696      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.04G      1.547      1.143      1.309        135        640: 100%|██████████| 412/412 [02:07<00:00,  3.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.74it/s]
#                    all        823       4838      0.683      0.626      0.691      0.388
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.05G      1.542      1.117      1.298        161        640:  41%|████      | 168/412 [00:54<01:19,  3.08it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2257738924.py in <cell line: 0>()
#       9
#      10 if os.path.exists(data_config_path):
# ---> 11     results = model.train(data=data_config_path, epochs=100, imgsz=640) # You can adjust epochs and imgsz
#      12     print("Training finished.")
#      13 else:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     797
#     798         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799         self.trainer.train()
#     800         # Update model and cfg after training
#     801         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in train(self)
#     225
#     226         else:
# --> 227             self._do_train(world_size)
#     228
#     229     def _setup_scheduler(self):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     417                 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     418                 if ni - last_opt_step >= self.accumulate:
# --> 419                     self.optimizer_step()
#     420                     last_opt_step = ni
#     421
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in optimizer_step(self)
#     640         self.scaler.unscale_(self.optimizer)  # unscale gradients
#     641         torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)  # clip gradients
# --> 642         self.scaler.step(self.optimizer)
#     643         self.scaler.update()
#     644         self.optimizer.zero_grad()
#
# /usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py in step(self, optimizer, *args, **kwargs)
#     455         ), "No inf checks were recorded for this optimizer."
#     456
# --> 457         retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     458
#     459         optimizer_state["stage"] = OptState.STEPPED
#
# /usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py in _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     350         retval: Optional[float] = None
#     351         if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 352             retval = optimizer.step(*args, **kwargs)
#     353         return retval
#     354
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#     138                     opt = opt_ref()
#     139                     opt._opt_called = True  # type: ignore[union-attr]
# --> 140                     return func.__get__(opt, opt.__class__)(*args, **kwargs)
#     141
#     142                 wrapper._wrapped_by_lr_sched = True  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     491                             )
#     492
# --> 493                 out = func(*args, **kwargs)
#     494                 self._optimizer_step_code()
#     495
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      89             torch.set_grad_enabled(self.defaults["differentiable"])
#      90             torch._dynamo.graph_break()
# ---> 91             ret = func(self, *args, **kwargs)
#      92         finally:
#      93             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/sgd.py in step(self, closure)
#     123             )
#     124
# --> 125             sgd(
#     126                 params,
#     127                 grads,
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/sgd.py in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, fused, grad_scale, found_inf, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     298         func = _single_tensor_sgd
#     299
# --> 300     func(
#     301         params,
#     302         d_p_list,
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/sgd.py in _multi_tensor_sgd(params, grads, momentum_buffer_list, grad_scale, found_inf, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     398                 torch._foreach_add_(device_grads, device_params, alpha=weight_decay)
#     399             else:
# --> 400                 device_grads = torch._foreach_add(  # type: ignore[assignment]
#     401                     device_grads, device_params, alpha=weight_decay
#     402                 )
#
# KeyboardInterrupt:
